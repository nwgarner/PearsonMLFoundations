# %% [markdown]
# # Module 1: ML Foundations and Types

# %% [markdown]
# # Module 2: Hands-On Model Building

# %% [markdown]
# # Module 3: ML Security Risks & Mitigations

# %% [markdown]
# # Module 4: Ethical ML, Resources & Wrap-Up
